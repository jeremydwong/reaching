# %% [markdown]
# # Energy and time optimizations for double-pendulum reaching model.
#
# In the following code we create a doublePendulum model and perform optimizations to find the trajectories and movement times for reaches of different distances, and different valuations of time.
#
# if you set 'theGeneratePlots=1', you will get 6 plots per optimization.

# %%
#%% Loop across distances and valuations to generate double-pendulum distance/time predictions. 
import DoublePendulumClass as dp
import numpy as np
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = ['svg']

# model that has equations to compute endpoint jacobians, equations of motion, and energy. 
sim = dp.kinarmModel()

x = 0.0
ys = 0.2
xystart = np.array([x,ys])

#loopValuation = [5, 3, 1, .75, .5, .25, .05, .01]
#loopdist = np.array([.0025, .005, .01, .02, .04, .06, .1, .2, .3, .5])
loopValuation = [15,5, 3, 1, .75, .5, .25, .05, .01]
loopdist = np.array([.0025, .005, .01, .02, .04, .06, .1, .2, .3, .5])
# loopValuation = [1]
# loopdist = np.array([.15])

distcolors = ['#f7fcf0','#e0f3db','#ccebc5','#a8ddb5','#7bccc4','#4eb3d3','#2b8cbe','#0868ac','#084081']

M = len(loopdist)
N = len(loopValuation)
duration = np.zeros([M, N])
J = np.zeros([M, N])
frCost = np.zeros([M, N])
workCost = np.zeros([M, N])
timeCost = np.zeros([M, N])
peakhandspeed = np.zeros([M, N])

# get all trajectories
trajRows = list()
trajCols = list() 

# get all optimization results
optiRows = list()
optiCols = list()

mDist = 0
nVal = 0
solution = []
for i in loopdist:
  for j in loopValuation:
    solution, \
      duration[mDist,nVal], J[mDist,nVal], workCost[mDist,nVal], frCost[mDist,nVal], timeCost[mDist,nVal], peakhandspeed[mDist,nVal],trajResult = \
      sim.movementTimeOpt(xystart,xystart + np.array([x,i]), \
      theTimeValuation=j,theN = 100, theGeneratePlots=0, LINEAR_GUESS=False, theDurationGuess = 1.1)
    nVal += 1
    trajCols.append(trajResult)
    optiCols.append(solution)
  nVal = 0
  mDist += 1
  trajRows.append(trajCols)
  optiRows.append(optiCols)
  trajCols = []
# %%
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     5628
# Number of nonzeros in inequality constraint Jacobian.:     2426
# Number of nonzeros in Lagrangian Hessian.............:     2518
#
# Total number of variables............................:     1819
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1028
# Total number of inequality constraints...............:     1416
#         inequality constraints with only lower bounds:      405
#    inequality constraints with lower and upper bounds:      202
#         inequality constraints with only upper bounds:      809
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.6500000e+01 5.30e-01 1.50e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.2264375e+01 6.35e-03 1.42e+01  -1.0 6.50e-01    -  1.34e-01 9.77e-01f  1
#    2  3.7993570e+01 8.95e-04 1.68e+02  -1.0 9.89e-01    -  6.21e-01 1.00e+00f  1
#    3  3.2787290e+01 1.58e-03 7.01e+03  -1.0 5.01e-01    -  4.88e-01 9.91e-01f  1
#    4  3.4640108e+01 2.85e-04 2.97e+01  -1.0 3.38e-01   0.0 1.00e+00 1.00e+00f  1
#    5  2.6307776e+01 2.50e-03 6.83e+01  -2.5 5.28e-01    -  6.71e-01 1.00e+00f  1
#    6  2.2132166e+01 8.22e-03 1.42e+06  -2.5 5.46e+00    -  2.28e-01 1.00e+00f  1
#    7  2.2132182e+01 8.21e-03 3.00e+06  -2.5 4.29e-06  11.8 1.00e+00 1.00e+00h  1
#    8r 2.2132182e+01 8.21e-03 1.00e+03  -2.1 0.00e+00  11.4 0.00e+00 4.77e-07R 22
#    9r 2.2372172e+01 1.65e-03 9.77e+02  -2.1 1.47e+02    -  2.96e-02 1.33e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.
#   66  9.9694717e-01 3.21e-03 2.36e+00  -5.7 8.59e+01    -  5.58e-01 6.64e-01h  1
#   67  9.9222581e-01 8.59e-04 1.14e+00  -5.7 2.16e+01    -  9.11e-01 8.39e-01f  1
#   68  9.9184877e-01 5.02e-04 8.63e+00  -5.7 8.49e+00    -  1.00e+00 4.18e-01h  1
#   69  9.9138910e-01 1.07e-05 1.74e-07  -5.7 3.81e+00    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  9.8971109e-01 5.16e-05 1.05e+01  -8.6 1.75e+01    -  5.52e-01 8.23e-01h  1
#   71  9.8946911e-01 2.03e-05 4.39e-01  -8.6 1.12e+01    -  7.37e-01 6.84e-01h  1
#   72  9.8939401e-01 6.35e-06 1.12e+01  -8.6 5.11e+00    -  9.64e-01 7.22e-01f  1
#   73  9.8937203e-01 1.29e-06 8.60e+00  -8.6 1.53e+00    -  9.97e-01 8.09e-01f  1
#   74  9.8936705e-01 4.58e-09 2.18e+01  -8.6 2.76e-01    -  4.18e-01 1.00e+00f  1
#   75  9.8936706e-01 3.52e-09 4.03e+01  -8.6 7.10e-03    -  4.07e-01 1.00e+00h  1
#   76  9.8936706e-01 3.17e-09 6.86e+01  -8.6 1.14e-04    -  1.94e-01 1.00e+00h  1
#   77  9.8936706e-01 4.21e-09 8.73e+01  -8.6 7.12e-07    -  1.49e-01 1.00e+00h  1
#   78  9.8936706e-01 5.17e-09 2.97e+01  -8.6 3.11e-08    -  1.35e-01 1.00e+00h  1
#   79  9.8936706e-01 2.12e-09 2.51e-14  -8.6 1.55e-08    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 79
#
#                                    (scaled)                 (unscaled)
# Objective...............:   9.8936705616239395e-01    9.8936705616239395e-01
# Dual infeasibility......:   2.5091040356528538e-14    2.5091040356528538e-14
# Constraint violation....:   2.1232903558646284e-09    2.1232903558646284e-09
# Complementarity.........:   2.7664518597795705e-09    2.7664518597795705e-09
# Overall NLP error.......:   2.7664518597795705e-09    2.7664518597795705e-09
#
#
# Number of objective function evaluations             = 127
# Number of objective gradient evaluations             = 80
# Number of equality constraint evaluations            = 127
# Number of inequality constraint evaluations          = 127
# Number of equality constraint Jacobian evaluations   = 80
# Number of inequality constraint Jacobian evaluations = 80
# Number of Lagrangian Hessian evaluations             = 79
# Total CPU secs in IPOPT (w/o function evaluations)   =      1.173
# Total CPU secs in NLP function evaluations           =      0.050
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
# callback_fun  | 359.15ms (  4.49ms) 361.15ms (  4.51ms)        80
#        nlp_f  |   2.39ms ( 18.83us)   2.38ms ( 18.73us)       127
#        nlp_g  |  13.18ms (103.81us)  13.13ms (103.40us)       127
#   nlp_grad_f  |   3.48ms ( 42.95us)   3.50ms ( 43.21us)        81
#   nlp_hess_l  |  13.70ms (173.46us)  16.06ms (203.29us)        79
#    nlp_jac_g  |  15.53ms (191.69us)  15.59ms (192.52us)        81
#        total  |   1.25 s (  1.25 s)   1.26 s (  1.26 s)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     5628
# Number of nonzeros in inequality constraint Jacobian.:     2426
# Number of nonzeros in Lagrangian Hessian.............:     2518
#
# Total number of variables............................:     1819
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1028
# Total number of inequality constraints...............:     1416
#         inequality constraints with only lower bounds:      405
#    inequality constraints with lower and upper bounds:      202
#         inequality constraints with only upper bounds:      809
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  5.5000000e-01 5.30e-01 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.0972549e+00 6.01e-03 1.85e+01  -1.0 6.49e-01    -  1.34e-01 9.79e-01f  1
#    2  2.5624256e+00 1.31e-03 2.04e+02  -1.0 1.06e+00    -  5.64e-01 1.00e+00f  1
#    3  3.1044121e+00 1.69e-03 2.75e+03  -1.0 7.26e-01    -  4.37e-01 6.45e-01f  1
#    4  4.8494233e+00 1.05e-03 1.86e+04  -1.0 9.97e-01    -  4.78e-01 9.93e-01f  1
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
# callback_fun  | 233.58ms (  5.70ms) 234.05ms (  5.71ms)        41
#        nlp_f  | 814.00us ( 19.38us) 809.83us ( 19.28us)        42
#        nlp_g  |   4.42ms (105.36us)   4.39ms (104.58us)        42
#   nlp_grad_f  |   1.80ms ( 42.83us)   1.80ms ( 42.76us)        42
#   nlp_hess_l  |   6.93ms (173.18us)   6.93ms (173.26us)        40
#    nlp_jac_g  |   7.97ms (189.74us)   7.95ms (189.34us)        42
#        total  | 538.37ms (538.37ms) 545.11ms (545.11ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     5628
# Number of nonzeros in inequality constraint Jacobian.:     2426
# Number of nonzeros in Lagrangian Hessian.............:     2518
#
# Total number of variables............................:     1819
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1028
# Total number of inequality constraints...............:     1416
#         inequality constraints with only lower bounds:      405
#    inequality constraints with lower and upper bounds:      202
#         inequality constraints with only upper bounds:      809
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  5.5000000e-02 1.90e+00 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.8438934e-02 1.73e+00 1.77e+00  -1.0 2.33e+00    -  4.15e-02 7.70e-02f  1
#    2  1.9313490e-01 9.31e-01 7.79e+00  -1.0 4.37e+00    -  6.81e-02 3.19e-01f  1
#    3  5.2241148e-01 2.19e-01 7.26e+00  -1.0 1.61e+00    -  2.49e-01 6.55e-01f  1
#    4  1.0796656e+00 8.51e-02 2.91e+00  -1.0 8.35e-01    -  6.86e-01 6.12e-01f  1
#    5  4.4703074e+00 2.97e-03 7.30e+01  -1.0 8.50e-01    -  3.77e-01 9.92e-01f  1
#    6  3.8528572e+00 2.00e-02 5.07e+03  -1.0 1.90e+00    -  5.05e-01 1.00e+00f  1
#    7  9.3606137e+00 2.12e-02 2.05e+03  -1.0 7.97e+00    -  3.62e-01 7.66e-01f  1
#    8  8.6089758e+00 1.14e-01 1.54e+03  -1.0 2.10e+01    -  4.99e-01 1.00e+00f  1
#    9  1.9585561e+01 9.60e-02 1.27e+03  -1.0 5.71e+01    -  3.97e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.7467335e+01 4.38e-01 8.73e+02  -1.0 1.39e+02    -  5.44e-01 1.00e+00f  1
#   11  3.3729414e+01 2.41e-01 8.68e+02  -1.0 4.84e+02    -  4.04e-01 1.00e+00f  1
#   12  3.4211133e+01 1.31e+00 4.96e+02  -1.0 9.31e+02    -  6.52e-01 1.00e+00f  1
#   13  5.7804289e+01 2.84e-01 5.54e+02  -1.0 3.00e+03    -  4.61e-01 1.00e+00f  1
#   14  7.1633352e+01 2.46e+00 2.34e+02  -1.0 4.87e+03    -  7.80e-01 1.00e+00f  1
#   15  1.1040664e+02 1.67e+00 1.79e+02  -1.0 9.14e+03    -  7.53e-01 1.00e+00f  1
#   16  1.4391854e+02 6.85e-01 8.57e+00  -1.0 6.92e+03    -  1.00e+00 1.00e+00f  1
#   17  1.5874157e+02 8.30e-02 7.54e-01  -1.0 2.83e+03    -  1.00e+00 1.00e+00h  1
#   18  4.7918781e+00 9.91e+00 9.14e+01  -1.7 2.95e+04    -  9.32e-01 9.27e-01f  1
#   19  3.9850004e+01 1.87e+00 4.09e+00  -1.7 4.05e+03    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  3.

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/casadi/casadi.py in <lambda>(self, name, value)
#    9549         __swig_setmethods__.update(getattr(_s, '__swig_setmethods__', {}))
# -> 9550     __setattr__ = lambda self, name, value: _swig_setattr(self, MX, name, value)
#    9551     __swig_getmethods__ = {}
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /var/folders/sl/7mntg4dj5cgf9kmjcvnlzfz40000gn/T/ipykernel_19671/963196693.py in <module>
#      45     solution, \
#      46       duration[mDist,nVal], J[mDist,nVal], workCost[mDist,nVal], frCost[mDist,nVal], timeCost[mDist,nVal], peakhandspeed[mDist,nVal],trajResult = \
# ---> 47       sim.movementTimeOpt(xystart,xystart + np.array([x,i]), \
#      48       theTimeValuation=j,theN = 100, theGeneratePlots=0, LINEAR_GUESS=False, theDurationGuess = 1.1)
#      49     nVal += 1
#
# ~/Git/optreach/doublepend/SimpleOpt.py in movementTimeOpt(self, theXYStart, theXYEnd, theN, theFRCoef, theTimeValuation, theGeneratePlots, theDuration, theDurationGuess, LINEAR_GUESS, sol)
#     147     def qd(qi, ui,acc): return ca.vertcat(qi[2], qi[3], acc[0], acc[1], qi[6],qi[7],ui[0],ui[1])  # dq/dt = f(q,u)
#     148     # Loop over discrete nodes and enforce calculus constraints.
# --> 149     HermiteSimpsonImplicit(opti,qd,self.implicitEOMQ,Q,ddqdt2,ddudt2,dt,[2,3])
#     150
#     151     mechPower = self.jointPower(dqdt,u)
#
# ~/Git/optreach/doublepend/SimpleOpt.py in HermiteSimpsonImplicit(opti, theDDTFun, theEOMImplicitFun, theQ, theQDotDot, theUIn, dt, indQDot)
#      38     opti.subject_to(theQ[:, k+1] - theQ[:, k] == dt/6 * (f + 4*fhalf + fnext))  # close the gaps
#      39     ### CONSTRAINT: Implicit dynamics, M*A - F = 0
# ---> 40     opti.subject_to(theEOMImplicitFun(theQ[:,k],theQDotDot[:,k]) == 0)
#      41
#      42 class SimpleModel:
#
# ~/Git/optreach/doublepend/DoublePendulumClass.py in implicitEOMQ(self, Q, acc)
#     151   # outputs: errors in the 0 constraint equation F - m*a = 0
#     152   def implicitEOMQ(self, Q, acc):
# --> 153     return self.implicitEOM(Q[0:2],Q[2:4],Q[4:6],acc)
#     154
#     155   # def kinematicJacobianInertias(self, q):
#
# ~/Git/optreach/doublepend/DoublePendulumClass.py in implicitEOM(self, q, qdot, u, qdotdot)
#     101       + self.m3*self.cx3**2 + self.m4*self.l3**2 + self.I2 + self.I3 + self.IHandMass + self.Imot2
#     102
# --> 103     F1 =  qdot[1]*(2*qdot[0] + qdot[1])*(self.ca2*self.l1*self.m2*ca.cos(q[1]) - self.ca4*self.l3*self.m4*ca.cos(self.Q25 - q[1]) \
#     104        + self.cx2*self.l1*self.m2*ca.sin(q[1]) + self.cHandMass*self.l1*self.mHandMass*ca.sin(q[1]) - \
#     105          self.cx4*self.l3*self.m4*ca.sin(self.Q25 - q[1]))
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/casadi/casadi.py in __sub__(x, y)
#    6109     def __add__(x, y): return _casadi.plus(x, y)
#    6110     def __radd__(x, y): return _casadi.plus(y, x)
# -> 6111     def __sub__(x, y): return _casadi.minus(x, y)
#    6112     def __rsub__(x, y): return _casadi.minus(y, x)
#    6113     def __mul__(x, y): return _casadi.times(x, y)
#
# SystemError: <built-in function minus> returned a result with an error set
# Error in callback <function flush_figures at 0x7f98a03b3670> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2232             if bbox_inches:
#    2233                 if bbox_inches == "tight":
# -> 2234                     bbox_inches = self.figure.get_tightbbox(
#    2235                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2236                     if pad_inches is None:
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    1637
#    1638         for a in artists:
# -> 1639             bbox = a.get_tightbbox(renderer)
#    1640             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    1641                 bb.append(bbox)
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4469             clip_extent = a._get_clipping_extent_bbox()
#    4470             if clip_extent is not None:
# -> 4471                 clip_extent = mtransforms.Bbox.intersection(
#    4472                     clip_extent, axbbox)
#    4473                 if np.all(clip_extent.extents == axbbox.extents):
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/transforms.py in intersection(bbox1, bbox2)
#     692         x0 = np.maximum(bbox1.xmin, bbox2.xmin)
#     693         x1 = np.minimum(bbox1.xmax, bbox2.xmax)
# --> 694         y0 = np.maximum(bbox1.ymin, bbox2.ymin)
#     695         y1 = np.minimum(bbox1.ymax, bbox2.ymax)
#     696         return Bbox([[x0, y0], [x1, y1]]) if x0 <= x1 and y0 <= y1 else None
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/transforms.py in ymin(self)
#     332     def ymin(self):
#     333         """The bottom edge of the bounding box."""
# --> 334         return np.min(self.get_points()[:, 1])
#     335
#     336     @property
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2877     6
#    2878     """
# -> 2879     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2880                           keepdims=keepdims, initial=initial, where=where)
#    2881
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:

# %%
solution

# %%
#%% Figure 1: distance / time 

f,ax = plt.subplots()
for v in range(0,len(loopValuation)):
#v = 0
  xtemp = loopdist.copy()
  y = duration.copy()
  y = y[:,v]
  ytemp = np.concatenate(([0],y))

  xtemp = np.concatenate(([0],xtemp))
  plt.plot(xtemp,ytemp,label=loopValuation[v],color = distcolors[v])
plt.legend()
# %%
plt.xlabel("Distance [m]")
plt.ylabel("Movement duration [s]")
ax.set_ylim(0,7)
# Out:
# (0.0, 7.0)

# %%
#%% Figure 2: distance peak speed / distance
f,ax = plt.subplots()
for v in range(0,len(loopValuation)):
#v = 0
  xtemp = loopdist.copy()
  y = peakhandspeed.copy()
  y = y[:,v]
  ytemp = np.concatenate(([0],y))

  xtemp = np.concatenate(([0],xtemp))
  plt.plot(xtemp,ytemp, label=loopValuation[v],color = distcolors[v])
  plt.xlabel("Distance [m]")
  plt.ylabel("Peak hand speed [m/s]")
  plt.legend()
# %%

# %%
#%% Figure 3: 3 valuations, hand speed vs time
def plotBells(theList):
  for i in range(0,len(theList)):
    tempStruct = theList[i]  
    plt.plot(tempStruct.time,tempStruct.handspeed,distcolors[i])

f,ax = plt.subplots()
plotBells(trajRows[0])
plotBells(trajRows[3])
plotBells(trajRows[-4])
plt.ylabel("Hand speed [m/s]")
plt.xlabel("Time [s]")

# %%
# #%% Figure 4: COST plot. 
# f,ax = plt.subplots()
# v = np.where(loopValuation ==1)

# xtemp = loopdist.copy()
# xtemp = np.concatenate(([0],xtemp))

# y = workCost.copy()
# y = y[:,v]
# ytemp = np.concatenate(([0],y))
# y2 = frCost.copy()
# y2 = y2[:,v]
# y2temp = np.concatenate([0],y2)

# plt.plot(xtemp,ytemp, label=loopValuation[v],color = distcolors[v])
# plt.plot(xtemp,ytemp, label=loopValuation[v],color = distcolors[v])
# d
# plt.xlabel("Distance [m]")
# plt.ylabel("Peak hand speed [m/s]")
# plt.legend()
# # %%
